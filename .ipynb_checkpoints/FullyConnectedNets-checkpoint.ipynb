# %% [markdown]
# # Fully-Connected Neural Nets
#   To demonstrate our neural net functions, we will use [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from Source.fc_net import *
from Source.data_utils import get_CIFAR10_data
#from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from Source.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %%
# for k, v in list(data.items()):
#     print(k)
print(data['X_train'].reshape(49000,-1).shape)
#print(data['X_train'].shape)
temp = data['X_train'].reshape(49000,-1)

a = data['X_train'].shape
print(a[0])
np.sum(temp.reshape(49000, 3, 32, 32) - data['X_train'])
# Out:
# (49000, 3072)
# 49000
# 0.0

# %% [markdown]
# # Two-layer network
#
# Implement the the function TwoLayerNet with the default values and optimize the loss function using Solver module. In this example, I'm using 'adam', but you can try different optimization techniques (sgd, sgd_momentum or rmsprop)

# %%
model = TwoLayerNet()
solver = None

solver = Solver(model, data,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                lr_decay=0.95,
                num_epochs=10, batch_size=100,
                print_every=100)
solver.train()
# Out:
# (Iteration 1 / 4900) loss: 2.302936
# (Epoch 0 / 10) train acc: 0.128000; val_acc: 0.149000
# (Iteration 101 / 4900) loss: 1.958055
# (Iteration 201 / 4900) loss: 2.040771
# (Iteration 301 / 4900) loss: 2.164851
# (Iteration 401 / 4900) loss: 2.166819
# (Epoch 1 / 10) train acc: 0.419000; val_acc: 0.375000
# (Iteration 501 / 4900) loss: 2.188373
# (Iteration 601 / 4900) loss: 1.590865
# (Iteration 701 / 4900) loss: 2.170439
# (Iteration 801 / 4900) loss: 1.665580
# (Iteration 901 / 4900) loss: 2.210172
# (Epoch 2 / 10) train acc: 0.360000; val_acc: 0.357000
# (Iteration 1001 / 4900) loss: 1.973710
# (Iteration 1101 / 4900) loss: 2.073898
# (Iteration 1201 / 4900) loss: 1.548725
# (Iteration 1301 / 4900) loss: 1.859650
# (Iteration 1401 / 4900) loss: 2.216236
# (Epoch 3 / 10) train acc: 0.419000; val_acc: 0.392000
# (Iteration 1501 / 4900) loss: 1.584703
# (Iteration 1601 / 4900) loss: 1.761338
# (Iteration 1701 / 4900) loss: 2.183085
# (Iteration 1801 / 4900) loss: 1.625677
# ...

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `Source/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout or batch normalization; we will add those features soon.

# %% [markdown]
# A good sanity check for our gradients is to make sure we can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. You will need to tweak the learning rate and initialization scale, but you should be able to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 4e-02 #1e-2
learning_rate = 6e-04 #1e-4
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 18.217993
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.108000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.280000; val_acc: 0.120000
# (Epoch 3 / 20) train acc: 0.580000; val_acc: 0.129000
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.123000
# (Epoch 5 / 20) train acc: 0.760000; val_acc: 0.121000
# (Iteration 11 / 40) loss: 2.344672
# (Epoch 6 / 20) train acc: 0.860000; val_acc: 0.125000
# (Epoch 7 / 20) train acc: 0.940000; val_acc: 0.136000
# (Epoch 8 / 20) train acc: 0.920000; val_acc: 0.134000
# (Epoch 9 / 20) train acc: 0.960000; val_acc: 0.136000
# (Epoch 10 / 20) train acc: 0.980000; val_acc: 0.125000
# (Iteration 21 / 40) loss: 0.094200
# (Epoch 11 / 20) train acc: 0.980000; val_acc: 0.134000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.135000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.138000
# ...

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

#weight_scale = 4e-02 #1e-2
#learning_rate = 6e-04 #1e-4

learning_rate = 4e-04
weight_scale = 2e-01
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 4059.110722
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.120000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.103000
# (Epoch 4 / 20) train acc: 0.340000; val_acc: 0.126000
# (Epoch 5 / 20) train acc: 0.480000; val_acc: 0.133000
# (Iteration 11 / 40) loss: 97.176734
# (Epoch 6 / 20) train acc: 0.480000; val_acc: 0.100000
# (Epoch 7 / 20) train acc: 0.520000; val_acc: 0.128000
# (Epoch 8 / 20) train acc: 0.680000; val_acc: 0.136000
# (Epoch 9 / 20) train acc: 0.780000; val_acc: 0.124000
# (Epoch 10 / 20) train acc: 0.580000; val_acc: 0.117000
# (Iteration 21 / 40) loss: 385.121555
# (Epoch 11 / 20) train acc: 0.840000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.139000
# (Epoch 13 / 20) train acc: 0.820000; val_acc: 0.143000
# (Epoch 14 / 20) train acc: 0.920000; val_acc: 0.146000
# ...

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochstic gradient descent.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than 1e-8.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 1e-2,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
    plt.subplot(3, 1, 1)
    plt.plot(solver.loss_history, 'o', label=update_rule)

    plt.subplot(3, 1, 2)
    plt.plot(solver.train_acc_history, '-o', label=update_rule)

    plt.subplot(3, 1, 3)
    plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
    plt.subplot(3, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 2.895827
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.102000
# (Iteration 11 / 200) loss: 2.230427
# (Iteration 21 / 200) loss: 2.092431
# (Iteration 31 / 200) loss: 2.039943
# (Epoch 1 / 5) train acc: 0.300000; val_acc: 0.274000
# (Iteration 41 / 200) loss: 2.048648
# (Iteration 51 / 200) loss: 2.002163
# (Iteration 61 / 200) loss: 2.001045
# (Iteration 71 / 200) loss: 1.814889
# (Epoch 2 / 5) train acc: 0.329000; val_acc: 0.295000
# (Iteration 81 / 200) loss: 1.816352
# (Iteration 91 / 200) loss: 1.902833
# (Iteration 101 / 200) loss: 1.834679
# (Iteration 111 / 200) loss: 1.804097
# (Epoch 3 / 5) train acc: 0.382000; val_acc: 0.305000
# (Iteration 121 / 200) loss: 1.757335
# (Iteration 131 / 200) loss: 1.646689
# (Iteration 141 / 200) loss: 1.733312
# (Iteration 151 / 200) loss: 1.705801
# (Epoch 4 / 5) train acc: 0.387000; val_acc: 0.318000
# (Iteration 161 / 200) loss: 1.718257
# (Iteration 171 / 200) loss: 1.801182
# ...

# %% [markdown]
# # RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `Source/optim.py`, we implemented the RMSProp update rule in the `rmsprop` function and implemented the Adam update rule in the `adam` function.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': learning_rates[update_rule]
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in list(solvers.items()):
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  adam
# (Iteration 1 / 200) loss: 2.479527
# (Epoch 0 / 5) train acc: 0.128000; val_acc: 0.157000
# (Iteration 11 / 200) loss: 1.987405
# (Iteration 21 / 200) loss: 2.148158
# (Iteration 31 / 200) loss: 1.880133
# (Epoch 1 / 5) train acc: 0.388000; val_acc: 0.332000
# (Iteration 41 / 200) loss: 1.732408
# (Iteration 51 / 200) loss: 1.868165
# (Iteration 61 / 200) loss: 1.770367
# (Iteration 71 / 200) loss: 1.659753
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.342000
# (Iteration 81 / 200) loss: 1.649113
# (Iteration 91 / 200) loss: 1.680308
# (Iteration 101 / 200) loss: 1.322598
# (Iteration 111 / 200) loss: 1.498709
# (Epoch 3 / 5) train acc: 0.498000; val_acc: 0.378000
# (Iteration 121 / 200) loss: 1.305712
# (Iteration 131 / 200) loss: 1.393856
# (Iteration 141 / 200) loss: 1.415497
# (Iteration 151 / 200) loss: 1.180366
# (Epoch 4 / 5) train acc: 0.549000; val_acc: 0.379000
# (Iteration 161 / 200) loss: 1.425779
# (Iteration 171 / 200) loss: 1.264286
# ...
